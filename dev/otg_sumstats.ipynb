# %%
import os
import os.path as osp
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
os.environ['JAVA_HOME'] = osp.join(os.environ['CONDA_PREFIX'].replace('ukb-analysis', 'pyspark'), 'jre')
spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# ### Single File EDA

# %%
import pandas as pd

# %% [markdown]
# #### Release 20022712

# %%
# !wget -P /tmp/ ftp://ftp.ebi.ac.uk/pub/databases/opentargets/genetics/20022712/v2d/part-00000-93eaa27c-13dc-436a-971b-c4dde2d9fc2d-c000.json
# Out:
# --2020-08-20 06:15:18--  ftp://ftp.ebi.ac.uk/pub/databases/opentargets/genetics/190505/v2d/part-00000-ed5e8444-cdf6-4706-9ce5-d6bce4603fcb-c000.json
#            => ‘/tmp/part-00000-ed5e8444-cdf6-4706-9ce5-d6bce4603fcb-c000.json’
# Resolving ftp.ebi.ac.uk (ftp.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.ebi.ac.uk (ftp.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/databases/opentargets/genetics/190505/v2d ... done.
# ==> SIZE part-00000-ed5e8444-cdf6-4706-9ce5-d6bce4603fcb-c000.json ... 28067347
# ==> PASV ... done.    ==> RETR part-00000-ed5e8444-cdf6-4706-9ce5-d6bce4603fcb-c000.json ... done.
# Length: 28067347 (27M) (unauthoritative)
#
# part-00000-ed5e8444 100%[===================>]  26.77M  17.5MB/s    in 1.5s
#
# 2020-08-20 06:15:20 (17.5 MB/s) - ‘/tmp/part-00000-ed5e8444-cdf6-4706-9ce5-d6bce4603fcb-c000.json’ saved [28067347]

# %%
df = pd.read_json('/tmp/part-00000-93eaa27c-13dc-436a-971b-c4dde2d9fc2d-c000.json', lines=True)
df.head()
# Out:
#                   study_id lead_chrom  lead_pos lead_ref lead_alt direction  \
# 0           GCST006585_850          1   1008088        T        C         +
# 1  NEALE2_20003_1140867876          1   1010747       GT        G         -
# 2        NEALE2_20002_1226          1   1370113        A        G         +
# 3          NEALE2_3064_raw          1   1389827        C        T         -
# 4               GCST004131          1   1280044        T        C         +
#
#       beta  beta_ci_lower  beta_ci_upper  pval_mantissa  ...  EUR_1000G_prop  \
# 0  0.73600       0.530930       0.941070        2.00000  ...             1.0
# 1      NaN            NaN            NaN        4.02417  ...             NaN
# 2      NaN            NaN            NaN        2.00827  ...             1.0
# 3 -2.30318      -2.938984      -1.667376        1.25000  ...             1.0
# 4      NaN            NaN            NaN        2.75200  ...             1.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57298 entries, 0 to 57297
# Data columns (total 42 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   study_id              57298 non-null  object
#  1   lead_chrom            57298 non-null  object
#  2   lead_pos              57298 non-null  int64
#  3   lead_ref              57298 non-null  object
#  4   lead_alt              57298 non-null  object
#  5   direction             45204 non-null  object
#  6   beta                  37756 non-null  float64
#  7   beta_ci_lower         37756 non-null  float64
#  8   beta_ci_upper         37756 non-null  float64
#  9   pval_mantissa         57298 non-null  float64
#  10  pval_exponent         57298 non-null  int64
#  11  pval                  57298 non-null  float64
#  12  pmid                  57293 non-null  object
#  13  pub_date              57298 non-null  object
#  14  pub_journal           57298 non-null  object
# ...

# %% [markdown]
# #### Release 190505

# %%
# !wget -P /tmp/ ftp://ftp.ebi.ac.uk/pub/databases/opentargets/genetics/190505/v2d/part-00000-ed5e8444-cdf6-4706-9ce5-d6bce4603fcb-c000.json

# %%
df = pd.read_json('/tmp/part-00000-ed5e8444-cdf6-4706-9ce5-d6bce4603fcb-c000.json', lines=True)
df.head()
# Out:
#                   study_id lead_chrom  lead_pos lead_ref lead_alt direction  \
# 0           GCST006585_850          1   1008088        T        C         +
# 1  NEALE2_20003_1140867876          1   1010747       GT        G         -
# 2           GCST006585_138          1   1227055        C        A         -
# 3         NEALE2_21001_raw          1   1851414       GA        G         +
# 4         NEALE2_23116_raw          1   2806649        C        A         -
#
#        beta  beta_ci_lower  beta_ci_upper  pval_mantissa  ...  EUR_1000G_prop  \
# 0  0.736000       0.530930       0.941070        2.00000  ...             1.0
# 1       NaN            NaN            NaN        4.02417  ...             NaN
# 2 -0.271000      -0.352458      -0.189542        7.00000  ...             1.0
# 3  0.066347       0.043588       0.089105        1.10563  ...             NaN
# 4 -0.020629      -0.027771      -0.013487        1.50401  ...             NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32409 entries, 0 to 32408
# Data columns (total 42 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   study_id              32409 non-null  object
#  1   lead_chrom            32409 non-null  object
#  2   lead_pos              32409 non-null  int64
#  3   lead_ref              32409 non-null  object
#  4   lead_alt              32409 non-null  object
#  5   direction             26443 non-null  object
#  6   beta                  21851 non-null  float64
#  7   beta_ci_lower         21851 non-null  float64
#  8   beta_ci_upper         21851 non-null  float64
#  9   pval_mantissa         32409 non-null  float64
#  10  pval_exponent         32409 non-null  int64
#  11  pval                  32409 non-null  float64
#  12  pmid                  32402 non-null  object
#  13  pub_date              32409 non-null  object
#  14  pub_journal           32409 non-null  object
# ...

# %% [markdown]
# #### Release 190504

# %%
# !wget -P /tmp/ ftp://ftp.ebi.ac.uk/pub/databases/opentargets/genetics/190504/v2d/part-00000-5fd0c32d-d124-4b78-9116-ff45c77577ce-c000.json
# Out:
# --2020-08-20 06:22:07--  ftp://ftp.ebi.ac.uk/pub/databases/opentargets/genetics/190504/v2d/part-00000-5fd0c32d-d124-4b78-9116-ff45c77577ce-c000.json
#            => ‘/tmp/part-00000-5fd0c32d-d124-4b78-9116-ff45c77577ce-c000.json’
# Resolving ftp.ebi.ac.uk (ftp.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.ebi.ac.uk (ftp.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/databases/opentargets/genetics/190504/v2d ... done.
# ==> SIZE part-00000-5fd0c32d-d124-4b78-9116-ff45c77577ce-c000.json ... 24777430
# ==> PASV ... done.    ==> RETR part-00000-5fd0c32d-d124-4b78-9116-ff45c77577ce-c000.json ... done.
# Length: 24777430 (24M) (unauthoritative)
#
# part-00000-5fd0c32d 100%[===================>]  23.63M  16.5MB/s    in 1.4s
#
# 2020-08-20 06:22:10 (16.5 MB/s) - ‘/tmp/part-00000-5fd0c32d-d124-4b78-9116-ff45c77577ce-c000.json’ saved [24777430]

# %%
df = pd.read_json('/tmp/part-00000-5fd0c32d-d124-4b78-9116-ff45c77577ce-c000.json', lines=True)
df.head()
# Out:
#                   study_id lead_chrom  lead_pos lead_ref lead_alt direction  \
# 0  NEALE2_20003_1140867876          1   1010747       GT        G         -
# 1           GCST006585_850          1   1008088        T        C         +
# 2           GCST006585_138          1   1227055        C        A         -
# 3         NEALE2_23116_raw          1   2806649        C        A         -
# 4         NEALE2_21002_raw          1   1934937        G        A         +
#
#    odds_ratio  oddsr_ci_lower  oddsr_ci_upper  pval_mantissa  ...  tag_chrom  \
# 0    0.346424        0.237266        0.505801        4.02417  ...          1
# 1         NaN             NaN             NaN        2.00000  ...          1
# 2         NaN             NaN             NaN        7.00000  ...          1
# 3         NaN             NaN             NaN        1.50401  ...          1
# 4         NaN             NaN             NaN        2.20476  ...          1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57298 entries, 0 to 57297
# Data columns (total 42 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   study_id              57298 non-null  object
#  1   lead_chrom            57298 non-null  object
#  2   lead_pos              57298 non-null  int64
#  3   lead_ref              57298 non-null  object
#  4   lead_alt              57298 non-null  object
#  5   direction             45204 non-null  object
#  6   beta                  37756 non-null  float64
#  7   beta_ci_lower         37756 non-null  float64
#  8   beta_ci_upper         37756 non-null  float64
#  9   pval_mantissa         57298 non-null  float64
#  10  pval_exponent         57298 non-null  int64
#  11  pval                  57298 non-null  float64
#  12  pmid                  57293 non-null  object
#  13  pub_date              57298 non-null  object
#  14  pub_journal           57298 non-null  object
# ...

# %%
df[df['study_id'].str.contains('NEALE2')].iloc[0]
# Out:
# study_id                                        NEALE2_20003_1140867876
# lead_chrom                                                            1
# lead_pos                                                        1010747
# lead_ref                                                             GT
# lead_alt                                                              G
# direction                                                             -
# beta                                                                NaN
# beta_ci_lower                                                       NaN
# beta_ci_upper                                                       NaN
# pval_mantissa                                                   4.02417
# pval_exponent                                                        -8
# pval                                                        4.02417e-08
# pmid
# pub_date                                                     2018-08-01
# pub_journal
# pub_title
# ...
